# %% [markdown]
# ### Dataset
#
# #### The dataset that was used for this project contains data regarding census...... https://www.kaggle.com/muonneutrino/us-census-demographic-data/data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
census = pd.read_csv('county_data.csv')

# %%
census.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
# 1     0.6      ...        1.0          1.4         3.9         26.4     85953
# 2     0.2      ...        1.8          1.5         1.6         24.1      8597
# 3     0.4      ...        0.6          1.5         0.7         28.8      8294
# 4     0.3      ...        0.9          0.4         2.3         34.9     22189
#
# ...

# %%
census.shape
# Out:
# (3220, 38)

# %%
census.describe()
# Out:
#            CensusId      TotalPop           Men         Women     Hispanic  \
# count   3220.000000  3.220000e+03  3.220000e+03  3.220000e+03  3220.000000
# mean   31393.605280  9.940935e+04  4.889694e+04  5.051241e+04    11.011522
# std    16292.078954  3.193055e+05  1.566813e+05  1.626620e+05    19.241380
# min     1001.000000  8.500000e+01  4.200000e+01  4.300000e+01     0.000000
# 25%    19032.500000  1.121800e+04  5.637250e+03  5.572000e+03     1.900000
# 50%    30024.000000  2.603500e+04  1.293200e+04  1.305700e+04     3.900000
# 75%    46105.500000  6.643050e+04  3.299275e+04  3.348750e+04     9.825000
# max    72153.000000  1.003839e+07  4.945351e+06  5.093037e+06    99.900000
#
#              White        Black       Native        Asian      Pacific  \
# count  3220.000000  3220.000000  3220.000000  3220.000000  3220.000000
# mean     75.428789     8.665497     1.723509     1.229068     0.082733
# std      22.932890    14.279122     7.253115     2.633079     0.734931
# ...

# %% [markdown]
# ### Reshaping the data

# %%
census_subset = census[['CensusId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic', 'Asian', 'Black', 'Native', 'Pacific']]

# %%
census_subset.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  Asian  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6    1.0   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5    0.7    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6    0.4   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2    0.1   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6    0.1    1.5
#
#    Native  Pacific
# 0     0.4      0.0
# 1     0.6      0.0
# 2     0.2      0.0
# 3     0.4      0.0
# 4     0.3      0.0

# %% [markdown]
# ## Melting

# %%
census_reshaped = census_subset.melt(id_vars=['CensusId', 'TotalPop', 'State', 'County','Men', 'Women'])
census_reshaped.head()
# Out:
#    CensusId  TotalPop    State   County    Men  Women  variable  value
# 0      1001     55221  Alabama  Autauga  26745  28476  Hispanic    2.6
# 1      1003    195121  Alabama  Baldwin  95314  99807  Hispanic    4.5
# 2      1005     26932  Alabama  Barbour  14497  12435  Hispanic    4.6
# 3      1007     22604  Alabama     Bibb  12073  10531  Hispanic    2.2
# 4      1009     57710  Alabama   Blount  28512  29198  Hispanic    8.6

# %% [markdown]
# ## Exploratory plots

# %% [markdown]
# ### Total population per county histogram

# %% [markdown]
# ### Employment per county histogram

# %% [markdown]
# ## Analytic Questions

# %% [markdown]
# ### Is there a correlation between the population and employment

# %% [markdown]
# ### What's the racial distribution across the US

# %%
### Boxplots per race
